# %%
import pandas as pd
import numpy as np
import re

# %%
debit_df = pd.read_csv("/content/debit_transactions_Jan-Aug_2023.csv")
debit_df
# Out:
#            Date                              Description  \
# 0    2023-08-10  CARIBOU COFFEE CO #1             081023
# 1    2023-08-10  KRISPY KREME #4110               081023
# 2    2023-08-10  CMSVEND*CV DENVER                081023
# 3    2023-08-10  CMSVEND*CV DENVER                081023
# 4    2023-08-10  PBC- DENVER CO3834               081023
# ..          ...                                      ...
# 626  2023-01-03                             Vasa Fitness
# 627  2023-01-03                                   Rokfin
# 628  2023-01-03                          YouTube Premium
# 629  2023-01-03                                 7-Eleven
# 630  2023-01-03                      Amazon Web Services
#
#                          Original Description          Category  Amount  \
# 0     CARIBOU COFFEE CO #1             081023  Category Pending   -4.66
# 1     KRISPY KREME #4110               081023  Category Pending  -89.78
# ...

# %%
columns = list(debit_df.columns)
columns
# Out:
# ['Date', 'Description', 'Original Description', 'Category', 'Amount', 'Status']

# %%
columns = [c.lower() for c in columns]
columns = [c.replace(' ', '_') for c in columns]
debit_df.columns = columns
debit_df[:59]
# Out:
#           date                              description  \
# 0   2023-08-10  CARIBOU COFFEE CO #1             081023
# 1   2023-08-10  KRISPY KREME #4110               081023
# 2   2023-08-10  CMSVEND*CV DENVER                081023
# 3   2023-08-10  CMSVEND*CV DENVER                081023
# 4   2023-08-10  PBC- DENVER CO3834               081023
# 5   2023-08-11                 USAA CREDIT CARD PAYMENT
# 6   2023-08-10                  Canteen Vending Machine
# 7   2023-08-09                              Xcel Energy
# 8   2023-08-09                                    Prezi
# 9   2023-08-09                            Take Car Wash
# 10  2023-08-09                  Canteen Vending Machine
# 11  2023-08-09                  Canteen Vending Machine
# 12  2023-08-08                      Arby's via DoorDash
# 13  2023-08-08                                 7-Eleven
# 14  2023-08-08                           Caribou Coffee
# 15  2023-08-08                                  PepsiCo
# ...

# %%
debit_df.drop(columns='status', inplace=True)
debit_df
# Out:
#            date                              description  \
# 0    2023-08-10  CARIBOU COFFEE CO #1             081023
# 1    2023-08-10  KRISPY KREME #4110               081023
# 2    2023-08-10  CMSVEND*CV DENVER                081023
# 3    2023-08-10  CMSVEND*CV DENVER                081023
# 4    2023-08-10  PBC- DENVER CO3834               081023
# ..          ...                                      ...
# 626  2023-01-03                             Vasa Fitness
# 627  2023-01-03                                   Rokfin
# 628  2023-01-03                          YouTube Premium
# 629  2023-01-03                                 7-Eleven
# 630  2023-01-03                      Amazon Web Services
#
#                          original_description          category  amount
# 0     CARIBOU COFFEE CO #1             081023  Category Pending   -4.66
# 1     KRISPY KREME #4110               081023  Category Pending  -89.78
# ...

# %%
debit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 631 entries, 0 to 630
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date                  631 non-null    object
#  1   description           631 non-null    object
#  2   original_description  631 non-null    object
#  3   category              631 non-null    object
#  4   amount                631 non-null    float64
# dtypes: float64(1), object(4)
# memory usage: 24.8+ KB

# %%
debit_df["date"] = pd.to_datetime(debit_df["date"])
debit_df["date"]
# Out:
# 0     2023-08-10
# 1     2023-08-10
# 2     2023-08-10
# 3     2023-08-10
# 4     2023-08-10
#          ...
# 626   2023-01-03
# 627   2023-01-03
# 628   2023-01-03
# 629   2023-01-03
# 630   2023-01-03
# Name: date, Length: 631, dtype: datetime64[ns]

# %%
debit_df["amount"].sum()
# Out:
# -6728.869999999995

# %%
debit_df.category.unique()
# Out:
# array(['Category Pending', 'Fast Food', 'Utilities',
#        'Electronics & Software', 'Service & Parts', 'Food & Dining',
#        'Gas', 'Coffee Shops', 'Cash', 'Restaurants',
#        'Newspapers & Magazines', 'Atm Fee', 'Interest Income',
#        'Mortgage Payment', 'Hosting', 'Paycheck', 'Mobile Phone',
#        'Movies & Dvds', 'Doctor', 'Music', 'Eyecare', 'Personal Care',
#        'Auto & Transport', 'Television', 'Shopping', 'Entertainment',
#        'Financial', 'Credit Card Payment', 'Sporting Goods',
#        'Gifts & Donations', 'Health & Fitness', 'Education', 'Check',
#        'Clothing', 'Business Services', 'Uncategorized', 'Bonus',
#        'Home Improvement', 'Dentist', 'Transfer', 'Groceries', 'Books',
#        'State Tax', 'Federal Tax', 'Laundry', 'Taxes', 'Parking', 'Gym'],
#       dtype=object)

# %%
debit_category_amounts_df = debit_df[["category", "amount"]]
debit_category_amounts_df
# Out:
#              category  amount
# 0    Category Pending   -4.66
# 1    Category Pending  -89.78
# 2    Category Pending   -1.35
# 3    Category Pending   -1.35
# 4    Category Pending   -2.10
# ..                ...     ...
# 626               Gym  -21.99
# 627     Entertainment  -14.99
# 628     Entertainment  -12.97
# 629               Gas   -7.32
# 630           Hosting   -1.05
#
# [631 rows x 2 columns]

# %%
from binascii import Incomplete
cztegory_totals_df = debit_category_amounts_df.groupby('category').agg("sum")
cztegory_totals_df.reset_index(inplace=True)
cztegory_totals_df
# Out:
#                   category    amount
# 0                  Atm Fee     20.95
# 1         Auto & Transport   -289.32
# 2                    Bonus    998.70
# 3                    Books   -147.55
# 4        Business Services    -47.00
# 5                     Cash  -1230.95
# 6         Category Pending  -7226.75
# 7                    Check  -3382.13
# 8                 Clothing  -2559.32
# 9             Coffee Shops   -258.31
# 10     Credit Card Payment -51146.35
# 11                 Dentist   -164.50
# 12                  Doctor   -123.44
# 13               Education   -268.13
# 14  Electronics & Software   -338.38
# 15           Entertainment  -2964.84
# 16                 Eyecare  -1530.16
# 17               Fast Food  -1008.35
# 18             Federal Tax  -1605.00
# 19               Financial  -2852.63
# 20           Food & Dining  -1771.66
# 21                     Gas  -1368.58
# 22       Gifts & Donations  -1455.00
# 23               Groceries   -369.66
# ...

# %%
debit_description_amounts_df = debit_df[["description", "amount"]]
debit_description_amounts_df
# Out:
#                                  description  amount
# 0    CARIBOU COFFEE CO #1             081023   -4.66
# 1    KRISPY KREME #4110               081023  -89.78
# 2    CMSVEND*CV DENVER                081023   -1.35
# 3    CMSVEND*CV DENVER                081023   -1.35
# 4    PBC- DENVER CO3834               081023   -2.10
# ..                                       ...     ...
# 626                             Vasa Fitness  -21.99
# 627                                   Rokfin  -14.99
# 628                          YouTube Premium  -12.97
# 629                                 7-Eleven   -7.32
# 630                      Amazon Web Services   -1.05
#
# [631 rows x 2 columns]

# %%
description_totals_df = debit_description_amounts_df.groupby('description').agg('sum')
description_totals_df.reset_index(inplace=True)
description_totals_df
# Out:
#          description   amount
# 0           7-Eleven -1254.98
# 1     AAA Membership  -185.00
# 2       AMC Theatres   -39.39
# 3     ATM Fee Rebate    20.95
# 4              Adobe   -30.79
# ..               ...      ...
# 133             Xbox   -72.89
# 134      Xcel Energy -1723.69
# 135  YouTube Premium   -90.79
# 136       Zappos.com  -122.86
# 137             eBay  -171.85
#
# [138 rows x 2 columns]

# %%
description_totals_df.sort_values(by=['description'], inplace=True)
description_totals_df[:50]
# Out:
#                                 description   amount
# 0                                  7-Eleven -1254.98
# 1                            AAA Membership  -185.00
# 2                              AMC Theatres   -39.39
# 3                            ATM Fee Rebate    20.95
# 4                                     Adobe   -30.79
# 5                               Agjeans.com  -411.84
# 6                       Amazon Web Services    -8.39
# 7                                     Apple -2341.72
# 8                                    Arby's   -10.91
# 9                       Arby's via DoorDash   -52.44
# 10              Bank of America Credit Card  -316.92
# 11                           Barnes & Noble   -80.96
# 12                Barnes & Noble Membership   -25.00
# 13              Baskin Robbins via DoorDash   -29.63
# 14                            Bible Gateway   -41.59
# 15                              Big O Tires  -116.53
# 16                     Blue FCU W 119th Ave  -922.00
# ...

# %%
description_totals_df[50:100]
# Out:
#                                 description    amount
# 50                                 DoorDash   -895.58
# 51                            Eurest Dining   -279.77
# 52                              ExpressToll    -75.60
# 53                                 Fandango    -38.16
# 54                          Fitness Gallery    -94.90
# 55                       Fleischmann Family   -164.50
# 56                       Foundation Hyundai    -28.72
# 57                 Four Sea Group I Payroll  77755.09
# 58   Front Range Family Eye Greenwood Vilco  -1530.16
# 59                                      GNC    -48.65
# 60                       Genesiscouncil.com    -55.00
# 61                          Good Times Thru    -17.68
# 62                          Gque Broomfield    -72.90
# 63                                Group Inc    -10.00
# 64                    Hogback Bbq and Grill    -45.00
# 65                        IHOP via DoorDash   -226.18
# ...

# %%
description_totals_df[100:]
# Out:
#                               description    amount
# 100                  Service Payment Plan   -447.15
# 101                                 Sonic   -110.37
# 102               South Denver Cardiology   -107.16
# 103                               Spotify    -54.00
# 104                             Starbucks   -207.77
# 105                     State of Colorado  20563.00
# 106           Store Merch Httpsgeneralffl    -54.49
# 107                                Subway    -34.12
# 108                 Synchrony Credit Card   -605.78
# 109                              T-Mobile  -1120.64
# 110                     TCBY via DoorDash    -39.31
# 111                         Take Car Wash   -319.92
# 112                                Target   -228.08
# 113                      The French Press     -4.08
# 114                 The Friends of Israel   -200.00
# 115                        The Home Depot    -94.10
# 116     The Officer Tatum Httpstheofficaz    -41.99
# ...

# %%
phone_pattern = r'\d{3}-\d{3}-\d{4}'
my_str = 'my phone numer is 123-456-7899 dude'
re.split(phone_pattern, my_str)[0]
# Out:
# 'my phone numer is '

# %%
debit_orig_description_amounts_df = debit_df[["original_description", "amount"]]
debit_orig_description_amounts_df['original_description'] = debit_orig_description_amounts_df['original_description'].map(lambda x: x.split('*')[0])
debit_orig_description_amounts_df['original_description'] = debit_orig_description_amounts_df['original_description'].map(lambda x: x.split('#')[0])
debit_orig_description_amounts_df['original_description'] = debit_orig_description_amounts_df['original_description'].map(lambda x: re.split(phone_pattern, x)[0])
debit_orig_description_amounts_df['original_description'] = debit_orig_description_amounts_df['original_description'].map(lambda x: re.split(r'dd ', x.lower())[0])
debit_orig_description_amounts_df
# Out:
# <ipython-input-148-308a865c752d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   debit_orig_description_amounts_df['original_description'] = debit_orig_description_amounts_df['original_description'].map(lambda x: x.split('*')[0])
# <ipython-input-148-308a865c752d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   debit_orig_description_amounts_df['original_description'] = debit_orig_description_amounts_df['original_description'].map(lambda x: x.split('#')[0])
# ...

# %%
debit_orig_description_totals_df = debit_orig_description_amounts_df.groupby('original_description').agg('sum')
debit_orig_description_totals_df.sort_values(by=['original_description'], inplace=True)
debit_orig_description_totals_df.reset_index(inplace=True)
debit_orig_description_totals_df[:50]
# Out:
#                         original_description    amount
# 0                                             -1661.21
# 1   203 take 5 car wash      broomfield   co   -319.92
# 2   224pepsiven9147678600    denver       co   -101.25
# 3   7-eleven                 broomfield   co    -83.36
# 4   7-eleven 33481           golden       co    -12.39
# 5   7-eleven7285 w 119th placbroomfield   co    -74.25
# 6   7eleven-fcti11275 main stbroomfield   co    -80.00
# 7   aaa acg mbr 006/dues-ar  3037538800   co   -185.00
# 8                                    adobe      -20.80
# 9                  adobe                         -9.99
# 10                 agjeans.com                 -411.84
# 11  amazon web services      aws.amazon.cowa     -8.39
# 12  amc 0092 w.minster pro   westminster  co    -39.39
# 13  apple comone apple park wcupertino    ca     -0.99
# 14                 apple.com/bill               -70.45
# 15                 apple.com/us               -2270.28
# ...

# %%
debit_orig_description_totals_df[50:100]
# Out:
#                         original_description    amount
# 50  e 470 express tolls      303-5373470  co    -75.60
# 51                                    ebay o   -171.85
# 52  eurest@lm dc             littleton    co   -279.77
# 53  fandango                 fandango.com ca    -38.16
# 54  fitness gallery          denver       co    -94.90
# 55  fleischmann family dentisbroomfield   co   -164.50
# 56  foundation hyundai       denver       co    -28.72
# 57              four sea group i payroll      77755.09
# 58  front range family eye c greenwood vilco  -1530.16
# 59                                      gnc     -48.65
# 60  good times dr thru 111   broomfield   co    -17.68
# 61                                   google     -90.79
# 62  hogback bbq and grill    littleton    co    -45.00
# 63                                       in     -60.00
# 64                             interest paid      0.83
# 65                                   intuit    -192.72
# ...

# %%
debit_orig_description_totals_df[100:]
# Out:
#                          original_description    amount
# 100  sei 41743                fort lupton  co    -12.88
# 101                 service payment plan        -447.15
# 102                           sonic drive in    -110.37
# 103  south denver cardiology  littleton    co   -107.16
# 104  sp butter cloth          httpsbutterclca   -299.97
# 105  sp daily grace co.       kristinschmucmd    -47.00
# 106  sp gf store merch        httpsgeneralffl    -54.49
# 107  sp jeremysrazors         httpswww.jeretn   -174.66
# 108  sp the officer tatum     httpstheofficaz    -41.99
# 109                 spotify                      -54.00
# 110                                       sq      -4.33
# 111  starbucks store 00252    greenwood vilco     -9.15
# 112  starbucks store 06508    estes park   co     -5.29
# 113  starbucks store 13426    erie         co     -6.29
# 114  starbucks store 47645    broomfield   co   -135.78
# 115  starbucks store 54769    broomfield   co    -51.26
# ...

# %% [markdown]
# ## Credit Card Analysis

# %%
cc_df = pd.read_csv("/content/cc_transactions_Jan-Aug_2023.csv")
cc_df
# Out:
#            Date               Description  \
# 0    2023-08-11                TARGET.COM
# 1    2023-08-11        KING SOOPERS #5086
# 2    2023-08-11    WALMART.COM 8009666546
# 3    2023-08-11  USAA CREDIT CARD PAYMENT
# 4    2023-08-08    AMAZON.COM AMZN.COM/BI
# ..          ...                       ...
# 495  2023-03-13                  PetSmart
# 496  2023-03-13          USAA Credit Card
# 497  2023-03-12              King Soopers
# 498  2023-03-12               Prime Video
# 499  2023-03-12                    Amazon
#
#                          Original Description             Category   Amount  \
# 0                                  TARGET.COM     Category Pending   -97.15
# 1                          KING SOOPERS #5086     Category Pending  -153.14
# 2                      WALMART.COM 8009666546     Category Pending  -245.42
# 3                    USAA CREDIT CARD PAYMENT     Category Pending  7127.51
# ...
